# %% [markdown]
# # Investigación 2

# %%
# generar código en python para simular una regresión lineal simple
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from scipy import stats
# Configuración de estilo para gráficos
sns.set(style="whitegrid")
# Generar datos sintéticos
np.random.seed(42)
n_samples = 100
X = np.random.rand(n_samples) * 10  # Variable independiente
# Relación lineal con ruido
y = 3 * X + np.random.randn(n_samples) * 5  # Variable dependiente
# Crear un DataFrame
data = pd.DataFrame({'X': X, 'y': y})
# Dividir los datos en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(data[['X']], data['y'], test_size=0.2, random_state=42)
# Crear el modelo de regresión lineal
model = LinearRegression()
model.fit(X_train, y_train)
# Hacer predicciones
y_pred = model.predict(X_test)
# Evaluar el modelo
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R^2 Score: {r2:.2f}')
# Coeficientes del modelo
print(f'Intercept: {model.intercept_:.2f}')
print(f'Coefficient: {model.coef_[0]:.2f}')
# Visualizar los resultados
plt.figure(figsize=(10, 6))
plt.scatter(data['X'], data['y'], color='blue', label='Datos reales')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Línea de regresión')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Regresión Lineal Simple')
plt.legend()
plt.show()
# Análisis de residuos
residuals = y_test - y_pred
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, color='purple')
plt.title('Distribución de los residuos')
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.show()
# Prueba de normalidad de los residuos
k2, p = stats.normaltest(residuals)
alpha = 0.05
print(f'Prueba de normalidad p-value: {p:.3f}')
if p < alpha:
    print("Los residuos no siguen una distribución normal (rechazamos H0)")
else:
    print("Los residuos siguen una distribución normal (no rechazamos H0)")
# Out:
# Mean Squared Error: 16.34
# R^2 Score: 0.81
# Intercept: 0.71
# Coefficient: 2.80
# Prueba de normalidad p-value: 0.097
# Los residuos siguen una distribución normal (no rechazamos H0)

# %% [markdown]
# Eso es todo
