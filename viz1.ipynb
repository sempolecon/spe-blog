# %% [markdown]
# # Visualización 1

# %%
# crear una visualización simple con matplotlib y datos sintéticos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.DataFrame({
    'X': np.random.randn(100),
    'y': np.random.randn(100)
})

plt.scatter(data['X'], data['y'])
plt.show()
