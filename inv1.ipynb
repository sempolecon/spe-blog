# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # A continuación un histograma

# %% [markdown]
# Esto es un histograma. Gracias.

# %%
x = np.random.normal(size=1000)
plt.hist(x, bins=30)
plt.title("Histograma de una distribución normal")
plt.show()
